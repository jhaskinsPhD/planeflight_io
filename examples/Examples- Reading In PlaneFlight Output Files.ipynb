# %% [markdown]
# # Reading In PlaneFlight Output Files from GEOS-Chem
#
# This notebook demonstrates how to use `planeflight_io` to read GEOS-Chem `plane.log` output files into pandas DataFrames or xarray Datasets, either individually or concatenated across multiple days.

# %%
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import os
import planeflight_io as pln

path_to_examples = os.getcwd()

# Paths to supporting files required by the read functions:
filepath = path_to_examples + '/datafiles_for_examples/'
spdb_yaml = filepath + 'species_database.yml'
config_yaml = filepath + 'geoschem_config.yml'

# %% [markdown]
# ## Option 1: Read a Single `plane.log` File
#
# `pln.read_planelog()` reads one `plane.log` file and returns:
# - **`df`** — a `pd.DataFrame` with one row per observation point and one column per sampled variable.
# - **`info_dict`** — a dictionary with metadata for every column in `df`. Each key is a variable name; its value is a dict containing at minimum `'Long_name'` and `'Units'`. Advected species entries also include `'MW_g'` and `'Formula'`.
#
# Two YAML files from your GEOS-Chem run directory are required:
#
# | Argument | File | Why it's needed |
# |---|---|---|
# | `spdb_yaml` | `species_database.yml` | Provides metadata (molecular weight, formula, long name, units) for every output column. Without it, `info_dict` entries will be incomplete. |
# | `config_yaml` | `geoschem_config.yml` | Identifies which output columns are advected tracers vs. other diagnostics, so the correct units can be assigned to each column. |
#
# Both files live in your GEOS-Chem run directory (the directory where you ran GEOS-Chem).
#
# **Units note:** If your input files used tracer *numbers* (recommended default), advected species concentrations will already be in `mol/mol`. If they used tracer *names*, concentrations will be in `molec/cm³` — use `convert2_molmol=True` in Option 2 to convert.

# %%
# outputs_nums/ contains plane.log files generated from input files that used
# tracer numbers — concentrations are already in mol/mol:
df, info_dict = pln.read_planelog(
    filepath + 'outputs_nums/plane.log.20170116',
    spdb_yaml=spdb_yaml,
    config_yaml=config_yaml,
)

# Print a summary of all variable metadata:
for var, meta in info_dict.items():
    print(f"{var:20s}  units={meta.get('Units', 'N/A'):15s}  {meta.get('Long_name', '')}")
# Out:
# plane.log output file:
#   (1) Data stored in a pandas dataframe saved at:
# 	/home/jhask/Code/planeflight_io/examples/datafiles_for_examples/outputs_nums/plane.log.csv
#   (2) Associated metadata in a dict with column names as keys saved at:
# 	/home/jhask/Code/planeflight_io/examples/datafiles_for_examples/outputs_nums/plane.log.yaml
# POINT                 units=unitless index   Flight track data point number (for reference)
# TYPE                  units=unitless         Aircraft/flight number ID or ground station ID. Same as input.
# LAT                   units=degrees          Latitude (-90 to 90 degrees) for each flight track point
# LON                   units=degrees          Longitude (-180 to 180 degrees) for each flight track point
# PRESS                 units=hPa              Pressure in hPa for each flight track point
# OBS                   units=Same as entered in input file.  Observation value from the flight campaign
# T_IND                 units=Unitless index   Time index of output
# P_I                   units=Unitless index   GEOS-Chem level index
# I_IND                 units=Unitless index   GEOS-Chem longitude index
# J_IND                 units=Unitless index   GEOS-Chem latitude index
# RO2                   units=mol/mol          Concentration of RO2 family
# AN                    units=mol/mol          Concentration of AN family
# NOy                   units=mol/mol          Concentration of NOy family
# GMAO_TEMP             units=K                Temperature
# GMAO_ABSH             units=unitless         Absolute humidity
# GMAO_SURF             units=cm2/cm3          Aerosol surface area
# GMAO_PSFC             units=hPa              Surface pressure
# GMAO_UWND             units=m/s              Zonal winds
# GMAO_VWND             units=m/s              Meridional winds
# GMAO_IIEV             units=unitless         GEOS-Chem grid box Longitude index
# GMAO_JJEV             units=unitless         GEOS-Chem grid box Latitude index
# GMAO_LLEV             units=unitless         GEOS-Chem grid box index Level index
# GMAO_RELH             units=%                Relative humidity
# GMAO_PSLV             units=hPa              Sea level pressure
# GMAO_AVGW             units=mol/mol          Water vapor mixing ratio
# GMAO_THTA             units=K                Potential temperature
# GMAO_PRES             units=hPa              Pressure at center of grid box
# AODC_SULF             units=unitless         Column aerosol optical depth for sulfate
# AODC_BLKC             units=unitless         Column aerosol optical depth for black carbon
# AODC_ORGC             units=unitless         Column aerosol optical depth for organic carbon
# AODC_SALA             units=unitless         Column aerosol optical depth for accumulation mode sea salt
# AODC_SALC             units=unitless         Column aerosol optical depth for coarse mode sea salt
# AODC_DUST             units=unitless         Column aerosol optical depth for dust
# AODB_SULF             units=unitless         Column aerosol optical depth for sulfate *below aircraft*
# AODB_BLKC             units=unitless         Column aerosol optical depth for black carbon *below aircraft*
# AODB_ORGC             units=unitless         Column aerosol optical depth for organic carbon *below aircraft*
# AODB_SALA             units=unitless         Column aerosol optical depth for accumulation mode sea salt *below aircraft*
# AODB_SALC             units=unitless         Column aerosol optical depth for coarse mode sea salt *below aircraft*
# AODB_DUST             units=unitless         Column aerosol optical depth for dust *below aircraft*
# ISOR_HPLUS            units=M                ISORROPIA/HTEP aerosol [H+]
# ISOR_PH               units=unitless         ISORROPIA/HTEP pH (Note: In a non-ideal system, pH can be negative!)
# ISOR_AH2O             units=ug/m3 (air)      ISORROPIA/HTEP aerosol water
# ISOR_HSO4             units=M                ISORROPIA/HTEP bifulfate
# TIME_LT               units=fractional hours  Local time
# AQAER_RAD             units=cm               Aqueous aerosol radius
# AQAER_SURF            units=cm2/cm3          Aqueous aerosol surface area
# ACET                  units=mol/mol          Concentration of Acetone
# ACTA                  units=mol/mol          Concentration of Acetic acid
# AERI                  units=mol/mol          Concentration of Iodine on aerosol
# ALD2                  units=mol/mol          Concentration of Acetaldehyde
# ALK4                  units=mol/mol          Concentration of Lumped >= C4 Alkanes
# AONITA                units=mol/mol          Concentration of Aerosol-phase organonitrates from aromatics
# AROMP4                units=mol/mol          Concentration of Generic C4 product of aromatics
# AROMP5                units=mol/mol          Concentration of C5 unsaturated dicarbonyl
# ATOOH                 units=mol/mol          Concentration of ATO2 peroxide
# BALD                  units=mol/mol          Concentration of Benzaldehyde
# BCPI                  units=mol/mol          Concentration of Hydrophilic black carbon aerosol
# BCPO                  units=mol/mol          Concentration of Hydrophobic black carbon aerosol
# BENZ                  units=mol/mol          Concentration of Benzene
# BENZP                 units=mol/mol          Concentration of Phenyl hydroperoxide
# Br                    units=mol/mol          Concentration of Atomic bromine
# Br2                   units=mol/mol          Concentration of Molecular Bromine
# BrCl                  units=mol/mol          Concentration of Bromine chloride
# BrNO2                 units=mol/mol          Concentration of Nitryl bromide
# BrNO3                 units=mol/mol          Concentration of Bromine nitrate
# BrO                   units=mol/mol          Concentration of Bromine monoxide
# BrSALA                units=mol/mol          Concentration of Fine sea salt bromine
# BrSALC                units=mol/mol          Concentration of Coarse sea salt bromine
# BUTDI                 units=mol/mol          Concentration of Butenedial
# BZCO3H                units=mol/mol          Concentration of Perbenzoic acid
# BZPAN                 units=mol/mol          Concentration of Peroxybenzoylnitrate
# C2H2                  units=mol/mol          Concentration of Acetylene (aka Ethyne)
# C2H4                  units=mol/mol          Concentration of Ethylene
# C2H6                  units=mol/mol          Concentration of Ethane
# C3H8                  units=mol/mol          Concentration of Propane
# CCl4                  units=mol/mol          Concentration of Carbon tetrachloride
# CFC11                 units=mol/mol          Concentration of CFC-11
# CFC113                units=mol/mol          Concentration of CFC-113
# CFC114                units=mol/mol          Concentration of CFC-114
# CFC115                units=mol/mol          Concentration of CFC-115
# CFC12                 units=mol/mol          Concentration of CFC-12
# CH2Br2                units=mol/mol          Concentration of Dibromomethane
# CH2Cl2                units=mol/mol          Concentration of Dichloromethane
# CH2I2                 units=mol/mol          Concentration of Diiodomethane
# CH2IBr                units=mol/mol          Concentration of Bromoiodomethane
# CH2ICl                units=mol/mol          Concentration of Chloroiodomethane
# CH2O                  units=mol/mol          Concentration of Formaldehyde
# CH3Br                 units=mol/mol          Concentration of Methyl bromide
# CH3CCl3               units=mol/mol          Concentration of Methyl chloroform
# CH3Cl                 units=mol/mol          Concentration of Chloromethane
# CH3I                  units=mol/mol          Concentration of Methyl iodide
# CH4                   units=mol/mol          Concentration of Methane
# CHBr3                 units=mol/mol          Concentration of Bromoform
# CHCl3                 units=mol/mol          Concentration of Chloroform
# Cl                    units=mol/mol          Concentration of Atomic chlorine
# Cl2                   units=mol/mol          Concentration of Molecular chlorine
# Cl2O2                 units=mol/mol          Concentration of Dichlorine dioxide
# ClNO2                 units=mol/mol          Concentration of Nitryl chloride
# ClNO3                 units=mol/mol          Concentration of Chlorine nitrate
# ClO                   units=mol/mol          Concentration of Chlorine monoxide
# ClOO                  units=mol/mol          Concentration of Chlorine dioxide
# CLOCK                 units=mol/mol          Concentration of Clock tracer for diagnosing age of air
# CO                    units=mol/mol          Concentration of Carbon monoxide
# CSL                   units=mol/mol          Concentration of Cresols
# DMS                   units=mol/mol          Concentration of Dimethyl sulfide
# DST1                  units=mol/mol          Concentration of Dust aerosol, Reff = 0.7 microns
# DST2                  units=mol/mol          Concentration of Dust aerosol, Reff = 1.4 microns
# DST3                  units=mol/mol          Concentration of Dust aerosol, Reff = 2.4 microns
# DST4                  units=mol/mol          Concentration of Dust aerosol, Reff = 4.5 microns
# EOH                   units=mol/mol          Concentration of Ethanol
# ETHLN                 units=mol/mol          Concentration of Ethanol nitrate
# ETHN                  units=mol/mol          Concentration of hydroxy-nitrooxy-ethane
# ETHP                  units=mol/mol          Concentration of hydroxy-hydroperoxy-ethane
# ETNO3                 units=mol/mol          Concentration of Ethyl nitrate
# ETP                   units=mol/mol          Concentration of Ethylhydroperoxide
# FURA                  units=mol/mol          Concentration of Furan
# GLYC                  units=mol/mol          Concentration of Glycoaldehyde
# GLYX                  units=mol/mol          Concentration of Glyoxal
# H1211                 units=mol/mol          Concentration of Halon 1211, Freon 12B1
# H1301                 units=mol/mol          Concentration of Halon 1301, Freon 13B1
# H2402                 units=mol/mol          Concentration of Halon 2402
# H2O                   units=mol/mol          Concentration of Water vapor
# H2O2                  units=mol/mol          Concentration of Hydrogen peroxide
# HAC                   units=mol/mol          Concentration of Hydroxyacetone
# HBr                   units=mol/mol          Concentration of Hypobromic acid
# HC5A                  units=mol/mol          Concentration of isoprene-4,1-hydroxyaldehyde
# HCFC123               units=mol/mol          Concentration of HCFC-123, Freon 123
# HCFC141b              units=mol/mol          Concentration of HCFC-141b, Freon 141b
# HCFC142b              units=mol/mol          Concentration of HCFC-142b, Freon 142b
# HCFC22                units=mol/mol          Concentration of HCFC-22, Freon 22
# HCl                   units=mol/mol          Concentration of Hydrochloric acid
# HCOOH                 units=mol/mol          Concentration of Formic acid
# HI                    units=mol/mol          Concentration of Hydrogen iodide
# HMHP                  units=mol/mol          Concentration of Hydroxymethyl hydroperoxide
# HMML                  units=mol/mol          Concentration of hydroxymethyl-methyl-a-lactone
# HMS                   units=mol/mol          Concentration of Hydroxymethanesulfonate
# HNO2                  units=mol/mol          Concentration of Nitrous acid
# HNO3                  units=mol/mol          Concentration of Nitric acid
# HNO4                  units=mol/mol          Concentration of Peroxynitric acid
# HOBr                  units=mol/mol          Concentration of Hypobromous acid
# HOCl                  units=mol/mol          Concentration of Hypochlorous acid
# HOI                   units=mol/mol          Concentration of Hypoiodous acid
# HONIT                 units=mol/mol          Concentration of 2nd gen monoterpene organic nitrate
# HPALD1                units=mol/mol          Concentration of d-4,1-C5-hydroperoxyaldehyde
# HPALD2                units=mol/mol          Concentration of d-1,4-C5-hydroperoxyaldehyde
# HPALD3                units=mol/mol          Concentration of b-2,1-C5-hydroperoxyaldehyde
# HPALD4                units=mol/mol          Concentration of b-3,4-C5-hydroperoxyaldehyde
# HPETHNL               units=mol/mol          Concentration of Hydroperoxy ethanal
# I                     units=mol/mol          Concentration of Atomic iodine
# I2                    units=mol/mol          Concentration of Molecular iodine
# I2O2                  units=mol/mol          Concentration of Diiodine dioxide
# I2O3                  units=mol/mol          Concentration of Diiodine trioxide
# I2O4                  units=mol/mol          Concentration of Diiodine tetraoxide
# IBr                   units=mol/mol          Concentration of Iodine monobromide
# ICHE                  units=mol/mol          Concentration of Isoprene hydroxy-carbonyl-epoxides
# ICl                   units=mol/mol          Concentration of Iodine monochloride
# ICN                   units=mol/mol          Concentration of Lumped isoprene carbonyl-nitrates
# ICPDH                 units=mol/mol          Concentration of Isoprene dihydroxy hydroperoxycarbonyl
# IDC                   units=mol/mol          Concentration of Lumped isoprene dicarbonyls
# IDCHP                 units=mol/mol          Concentration of Isoprene dicarbonyl hydroxy dihydroperoxide
# IDHDP                 units=mol/mol          Concentration of Isoprene dihydroxy dihydroperoxide
# IDHPE                 units=mol/mol          Concentration of Isoprene dihydroxy hydroperoxy epoxide
# IDN                   units=mol/mol          Concentration of Lumped isoprene dinitrates
# IEPOXA                units=mol/mol          Concentration of trans-Beta isoprene epoxydiol
# IEPOXB                units=mol/mol          Concentration of cis-Beta isoprene epoxydiol
# IEPOXD                units=mol/mol          Concentration of Delta isoprene epoxydiol
# IHN1                  units=mol/mol          Concentration of Isoprene-d-4,1-hydroxynitrate
# IHN2                  units=mol/mol          Concentration of Isoprene-b-1,2-hydroxynitrate
# IHN3                  units=mol/mol          Concentration of Isoprene-b-4,3-hydroxynitrate
# IHN4                  units=mol/mol          Concentration of Isoprene-d-4,1-hydroxynitrate
# INDIOL                units=mol/mol          Concentration of Generic aerosol-phase organonitrate hydrolysis product
# INO                   units=mol/mol          Concentration of Nitrosyl iodide
# INPB                  units=mol/mol          Concentration of Lumped b-hydroperoxy isoprene nitrates
# INPD                  units=mol/mol          Concentration of Lumped d-hydroperoxy isoprene nitrates
# IO                    units=mol/mol          Concentration of Iodine monoxide
# IONITA                units=mol/mol          Concentration of Aer-phase organic nitrate from isoprene precursors
# IONO                  units=mol/mol          Concentration of Nitryl iodide
# IONO2                 units=mol/mol          Concentration of Iodine nitrate
# IPRNO3                units=mol/mol          Concentration of Isopropyl nitrate
# ISALA                 units=mol/mol          Concentration of Fine sea salt iodine
# ISALC                 units=mol/mol          Concentration of Coarse sea salt iodine
# ISOP                  units=mol/mol          Concentration of Isoprene
# ITCN                  units=mol/mol          Concentration of lumped isoprene tetrafunctional carbonylnitrates
# ITHN                  units=mol/mol          Concentration of Lumped isoprene tetrafunctional hydroxynitrates
# LIMO                  units=mol/mol          Concentration of Limonene
# LVOC                  units=mol/mol          Concentration of Gas-phase low-volatility non-IEPOX product of RIP ox
# LVOCOA                units=mol/mol          Concentration of Aer-phase low-volatility non-IEPOX product of RIP ox
# MACR                  units=mol/mol          Concentration of Methacrolein
# MACR1OOH              units=mol/mol          Concentration of Peracid from MACR
# MAP                   units=mol/mol          Concentration of Peroxyacetic acid
# MCRDH                 units=mol/mol          Concentration of Dihydroxy-methacrolein
# MCRENOL               units=mol/mol          Concentration of Lumped enols from MVK/MACR
# MCRHN                 units=mol/mol          Concentration of Nitrate from MACR
# MCRHNB                units=mol/mol          Concentration of Nitrate from MACR
# MCRHP                 units=mol/mol          Concentration of Hydroxy-hydroperoxy-methacrolein
# MCT                   units=mol/mol          Concentration of Catechols and methyl catechols
# MEK                   units=mol/mol          Concentration of Methyl Ethyl Ketone
# MENO3                 units=mol/mol          Concentration of Methyl nitrate
# MGLY                  units=mol/mol          Concentration of Methylglyoxal
# MOH                   units=mol/mol          Concentration of Methanol
# MONITA                units=mol/mol          Concentration of Aer-phase organic nitrate from monoterpene precursors
# MONITS                units=mol/mol          Concentration of Saturated 1st gen monoterpene organic nitrate
# MONITU                units=mol/mol          Concentration of Unsaturated 1st gen monoterpene organic nitrate
# MP                    units=mol/mol          Concentration of Methyl hydro peroxide
# MPAN                  units=mol/mol          Concentration of Peroxymethacroyl nitrate (PMN)
# MPN                   units=mol/mol          Concentration of Methyl peroxy nitrate
# MSA                   units=mol/mol          Concentration of Methyl sulfonic acid
# MTPA                  units=mol/mol          Concentration of a-pinene, b-pinene, sabinene, carene
# MTPO                  units=mol/mol          Concentration of Terpinene, terpinolene, myrcene, ocimene, other monoterpenes
# MVK                   units=mol/mol          Concentration of Methyl vinyl ketone
# MVKDH                 units=mol/mol          Concentration of dihydroxy-MVK
# MVKHC                 units=mol/mol          Concentration of MVK hydroxy-carbonyl
# MVKHCB                units=mol/mol          Concentration of MVK hydroxy-carbonyl
# MVKHP                 units=mol/mol          Concentration of MVK hydroxy-hydroperoxide
# MVKN                  units=mol/mol          Concentration of Nitrate from MVK
# MVKPC                 units=mol/mol          Concentration of MVK hydroperoxy-carbonyl
# N2O                   units=mol/mol          Concentration of Nitrous oxide
# N2O5                  units=mol/mol          Concentration of Dinitrogen pentoxide
# NH3                   units=mol/mol          Concentration of Ammonia
# NH4                   units=mol/mol          Concentration of Ammonium
# NIT                   units=mol/mol          Concentration of Inorganic nitrates
# NITs                  units=mol/mol          Concentration of Inorganic nitrates on surface of seasalt aerosol
# NO                    units=mol/mol          Concentration of Nitrogen oxide
# NO2                   units=mol/mol          Concentration of Nitrogen dioxide
# NO3                   units=mol/mol          Concentration of Nitrate radical
# NPHEN                 units=mol/mol          Concentration of Nitrophenols
# NPRNO3                units=mol/mol          Concentration of n-propyl nitrate
# O3                    units=mol/mol          Concentration of Ozone
# OClO                  units=mol/mol          Concentration of Chlorine dioxide
# OCPI                  units=mol/mol          Concentration of Hydrophilic organic carbon aerosol
# OCPO                  units=mol/mol          Concentration of Hydrophobic organic carbon aerosol
# OCS                   units=mol/mol          Concentration of Carbonyl sulfide
# OIO                   units=mol/mol          Concentration of Iodine dioxide
# PAN                   units=mol/mol          Concentration of Peroxyacetyl nitrate
# pFe                   units=mol/mol          Concentration of Anthropogenic iron
# PHEN                  units=mol/mol          Concentration of Phenol
# PIP                   units=mol/mol          Concentration of Peroxide from MTPA
# PP                    units=mol/mol          Concentration of Peroxide from PO2
# PPN                   units=mol/mol          Concentration of Lumped peroxypropionyl nitrate
# PROPNN                units=mol/mol          Concentration of Propanone nitrate
# PRPE                  units=mol/mol          Concentration of Lumped >= C3 alkenes
# PRPN                  units=mol/mol          Concentration of Peroxide from PRN1
# PYAC                  units=mol/mol          Concentration of Pyruvic acid
# R4N2                  units=mol/mol          Concentration of Lumped alkyl nitrate
# R4P                   units=mol/mol          Concentration of Peroxide from R4O2
# RA3P                  units=mol/mol          Concentration of Peroxide from A3O2
# RB3P                  units=mol/mol          Concentration of Peroxide from B3O2
# RCHO                  units=mol/mol          Concentration of Lumped aldehyde >= C3
# RIPA                  units=mol/mol          Concentration of 1,2-ISOPOOH
# RIPB                  units=mol/mol          Concentration of 4,3-ISOPOOH
# RIPC                  units=mol/mol          Concentration of d-1,4-ISOPOOH
# RIPD                  units=mol/mol          Concentration of d-4,1-ISOPOOH
# RP                    units=mol/mol          Concentration of Peroxide from RCO3
# SALA                  units=mol/mol          Concentration of Fine (0.01-0.05 microns) sea salt aerosol
# SALAAL                units=mol/mol          Concentration of Accumulation mode sea salt alkalinity
# SALACL                units=mol/mol          Concentration of Chloride in Accumulation mode sea salt aerosol
# SALC                  units=mol/mol          Concentration of Coarse (0.5-8 microns) sea salt aerosol
# SALCAL                units=mol/mol          Concentration of Coarse mode sea salt alkalinity
# SALCCL                units=mol/mol          Concentration of Chloride in Coarse mode sea salt aerosol
# SO2                   units=mol/mol          Concentration of Sulfur dioxide
# SO4                   units=mol/mol          Concentration of Sulfate
# SO4s                  units=mol/mol          Concentration of Sulfate on surface of seasalt aerosol
# SOAGX                 units=mol/mol          Concentration of Aerosol-phase glyoxal
# SOAIE                 units=mol/mol          Concentration of Aerosol-phase IEPOX
# SOAP                  units=mol/mol          Concentration of SOA Precursor - lumped species for simplified SOA parameterization
# SOAS                  units=mol/mol          Concentration of SOA Simple - simplified non-volatile SOA parameterization
# TOLU                  units=mol/mol          Concentration of Toluene
# XYLE                  units=mol/mol          Concentration of Xylene
# PlaneLog_File         units=N/A              Original path to raw plane.log file this data came from.
# File_Index            units=N/A              File index of all plane.log files concatenated this data came from.
# /tmp/ipykernel_72081/3222324694.py:3: UserWarning: The output directory passed to read_planelog() could not be found:
#
#  Output will be saved at input planelog file directory instead.
#   df, info_dict = pln.read_planelog(

# %% [markdown]
# ## Option 2: Concatenate Multiple `plane.log` Files
#
# `pln.read_and_concat_planelogs()` reads all `plane.log` files in a directory, concatenates them, and optionally saves the result as a NetCDF file.
#
# Key arguments:
#
# | Argument | Description |
# |---|---|
# | `convert2_molmol` | Set `True` if input files used tracer *names* (outputs are in `molec/cm³`) |
# | `as_xarr` | Set `True` to return an xarray Dataset |
# | `output_dir` + `output_file` | Where to save the concatenated NetCDF |
#
# **Workflow tip:** Run with `concat=True` once after getting GEOS-Chem output, then set `concat=False` to load the saved file on subsequent runs. This avoids re-reading and re-concatenating every time.

# %%
concat = False  # Set to True to (re-)create the concatenated file

if concat:
    if os.path.isfile(filepath + 'all_PlaneLogs.nc'):
        os.remove(filepath + 'all_PlaneLogs.nc')

    # outputs_names/ used tracer names → concentrations in molec/cm³ → convert:
    ds = pln.read_and_concat_planelogs(
        filepath + 'outputs_names/',
        spdb_yaml=spdb_yaml,
        config_yaml=config_yaml,
        as_xarr=True,
        convert2_molmol=True,
        output_dir=filepath,
        output_file='all_PlaneLogs',
        overwrite=True,
    )
else:
    ds = xr.open_dataset(filepath + 'all_PlaneLogs.nc')

print(ds)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/micromamba/envs/geoscipy/lib/python3.11/site-packages/xarray/backends/file_manager.py:219, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     218 try:
# --> 219     file = self._cache[self._key]
#     220 except KeyError:
#
# File ~/micromamba/envs/geoscipy/lib/python3.11/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/jhask/Code/planeflight_io/examples/datafiles_for_examples/all_PlaneLogs.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'eaefd496-8cee-4f22-9d73-bfa9bea8944d']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 19
#       8     ds = pln.read_and_concat_planelogs(
#       9         filepath + 'outputs_names/',
#      10         spdb_yaml=spdb_yaml,
#    (...)
#      16         overwrite=True,
#      17     )
#      18 else:
# ---> 19     ds = xr.open_dataset(filepath + 'all_PlaneLogs.nc')
#      21 print(ds)
#
# File ~/micromamba/envs/geoscipy/lib/python3.11/site-packages/xarray/backends/api.py:606, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, create_default_indexes, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     594 decoders = _resolve_decoders_kwargs(
#     595     decode_cf,
#     596     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     602     decode_coords=decode_coords,
#     603 )
#     605 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 606 backend_ds = backend.open_dataset(
#     607     filename_or_obj,
#     608     drop_variables=drop_variables,
#     609     **decoders,
#     610     **kwargs,
#     611 )
#     612 ds = _dataset_from_backend_dataset(
#     613     backend_ds,
#     614     filename_or_obj,
#    (...)
#     625     **kwargs,
#     626 )
#     627 return ds
#
# File ~/micromamba/envs/geoscipy/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:767, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, auto_complex, lock, autoclose)
#     745 def open_dataset(
#     746     self,
#     747     filename_or_obj: T_PathFileOrDataStore,
#    (...)
#     764     autoclose=False,
#     765 ) -> Dataset:
#     766     filename_or_obj = _normalize_path(filename_or_obj)
# --> 767     store = NetCDF4DataStore.open(
#     768         filename_or_obj,
#     769         mode=mode,
#     770         format=format,
#     771         group=group,
#     772         clobber=clobber,
#     773         diskless=diskless,
#     774         persist=persist,
#     775         auto_complex=auto_complex,
#     776         lock=lock,
#     777         autoclose=autoclose,
#     778     )
#     780     store_entrypoint = StoreBackendEntrypoint()
#     781     with close_on_error(store):
#
# File ~/micromamba/envs/geoscipy/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:525, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, auto_complex, lock, lock_maker, autoclose)
#     521 else:
#     522     manager = CachingFileManager(
#     523         netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     524     )
# --> 525 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File ~/micromamba/envs/geoscipy/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:429, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     427 self._group = group
#     428 self._mode = mode
# --> 429 self.format = self.ds.data_model
#     430 self._filename = self.ds.filepath()
#     431 self.is_remote = is_remote_uri(self._filename)
#
# File ~/micromamba/envs/geoscipy/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:534, in NetCDF4DataStore.ds(self)
#     532 @property
#     533 def ds(self):
# --> 534     return self._acquire()
#
# File ~/micromamba/envs/geoscipy/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:528, in NetCDF4DataStore._acquire(self, needs_lock)
#     527 def _acquire(self, needs_lock=True):
# --> 528     with self._manager.acquire_context(needs_lock) as root:
#     529         ds = _nc4_require_group(root, self._group, self._mode)
#     530     return ds
#
# File ~/micromamba/envs/geoscipy/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/micromamba/envs/geoscipy/lib/python3.11/site-packages/xarray/backends/file_manager.py:207, in CachingFileManager.acquire_context(self, needs_lock)
#     204 @contextmanager
#     205 def acquire_context(self, needs_lock: bool = True) -> Iterator[T_File]:
#     206     """Context manager for acquiring a file."""
# --> 207     file, cached = self._acquire_with_cache_info(needs_lock)
#     208     try:
#     209         yield file
#
# File ~/micromamba/envs/geoscipy/lib/python3.11/site-packages/xarray/backends/file_manager.py:225, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     223     kwargs = kwargs.copy()
#     224     kwargs["mode"] = self._mode
# --> 225 file = self._opener(*self._args, **kwargs)
#     226 if self._mode == "w":
#     227     # ensure file doesn't get overridden when opened again
#     228     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2517, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2154, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jhask/Code/planeflight_io/examples/datafiles_for_examples/all_PlaneLogs.nc'

# %% [markdown]
# ## Plotting the Output
#
# Once you have an xarray Dataset, you can plot model output directly against time or observation data.

# %%
tracer = 'O3'
print('Units of', tracer, ': mol mol\u207b\u00b9 \u00d7 1e9 = ppbv')

plt.plot(ds.time_UTC, ds[tracer] * 1e9, label='Model', linewidth=2)
plt.title(tracer + ' (ppbv)')
plt.xlabel('Time (UTC)')
plt.ylabel('Concentration (ppbv)')
plt.legend()
plt.tight_layout()
plt.show()
